# %%
import pandas as pd

# %%
teste_df = pd.read_excel("notas_planilha_pronta._v2xlsx.xlsx")
display(teste_df)
# Out:
#    Disciplina:                             ⠀⠀⠀⠀⠀⠀⠀⠀⠀  \
# 0           RM                                  Nome
# 1        82712                Ariele Justino Arantes
# 2        86543              Bruna Aparecida de Souza
# 3        89457                    Camila da Assunção
# 4        87257                Cyntia Araújo de Souza
# 5        80211                      Eduardo Ferreira
# 6        88683                   Elisa Dias Fernades
# 7        81931             Gabriel do Carmo da Silva
# 8        81203         Giovanna Ruth Alves dos Satos
# 9        82543            Guilherme Augusto Castilho
# 10       87384                Jessé da Silva Fontana
# 11       88481            Leonardo Brito de Oliveira
# 12       82561              Lucas dos Santos Batista
# 13       89228          Natalia Sofia Roque da Costa
# 14       89360                  Renata Pereira Pinto
# 15       88185            Tamires Tavares dos Santos
# 16       88075  Tatiane Antonia Nascimento de Araújo
# ...

# %%
teste_df.dropna
display(teste_df)
# Out:
#    Disciplina:                             ⠀⠀⠀⠀⠀⠀⠀⠀⠀  \
# 0           RM                                  Nome
# 1        82712                Ariele Justino Arantes
# 2        86543              Bruna Aparecida de Souza
# 3        89457                    Camila da Assunção
# 4        87257                Cyntia Araújo de Souza
# 5        80211                      Eduardo Ferreira
# 6        88683                   Elisa Dias Fernades
# 7        81931             Gabriel do Carmo da Silva
# 8        81203         Giovanna Ruth Alves dos Satos
# 9        82543            Guilherme Augusto Castilho
# 10       87384                Jessé da Silva Fontana
# 11       88481            Leonardo Brito de Oliveira
# 12       82561              Lucas dos Santos Batista
# 13       89228          Natalia Sofia Roque da Costa
# 14       89360                  Renata Pereira Pinto
# 15       88185            Tamires Tavares dos Santos
# 16       88075  Tatiane Antonia Nascimento de Araújo
# ...

# %%
rm = teste_df[["Disciplina:", "⠀⠀⠀⠀⠀⠀⠀⠀⠀"]]
display(rm)
# Out:
#    Disciplina:                             ⠀⠀⠀⠀⠀⠀⠀⠀⠀
# 0           RM                                  Nome
# 1        82712                Ariele Justino Arantes
# 2        86543              Bruna Aparecida de Souza
# 3        89457                    Camila da Assunção
# 4        87257                Cyntia Araújo de Souza
# 5        80211                      Eduardo Ferreira
# 6        88683                   Elisa Dias Fernades
# 7        81931             Gabriel do Carmo da Silva
# 8        81203         Giovanna Ruth Alves dos Satos
# 9        82543            Guilherme Augusto Castilho
# 10       87384                Jessé da Silva Fontana
# 11       88481            Leonardo Brito de Oliveira
# 12       82561              Lucas dos Santos Batista
# 13       89228          Natalia Sofia Roque da Costa
# 14       89360                  Renata Pereira Pinto
# 15       88185            Tamires Tavares dos Santos
# 16       88075  Tatiane Antonia Nascimento de Araújo
# ...

# %%
teste_df2 = pd.read_csv("notas_planilha_pronta_csvTeste.csv", encoding = "ISO-8859-1", sep = ";")
teste_df2.dropna(axis=1)
display(teste_df2)
# Out:
#    Disciplina:                            Unnamed: 1  \
# 0          NaN                                   NaN
# 1           RM                                  Nome
# 2        82712                Ariele Justino Arantes
# 3        86543              Bruna Aparecida de Souza
# 4        89457                    Camila da Assunção
# 5        87257                Cyntia Araújo de Souza
# 6        80211                      Eduardo Ferreira
# 7        88683                   Elisa Dias Fernades
# 8        81931             Gabriel do Carmo da Silva
# 9        81203         Giovanna Ruth Alves dos Satos
# 10       82543            Guilherme Augusto Castilho
# 11       87384                Jessé da Silva Fontana
# 12       88481            Leonardo Brito de Oliveira
# 13       82561              Lucas dos Santos Batista
# 14       89228          Natalia Sofia Roque da Costa
# 15       89360                  Renata Pereira Pinto
# 16       88185            Tamires Tavares dos Santos
# ...

# %%
faltantes = teste_df.isnull().sum()
print(faltantes)
# Out:
# Disciplina:                             1
# Unnamed: 1                              1
# Computational Thinking using Python     1
# Unnamed: 3                             22
# Unnamed: 4                              0
# Unnamed: 5                              1
# Unnamed: 6                              1
# Unnamed: 7                             22
# Unnamed: 8                              1
# Unnamed: 9                              1
# Unnamed: 10                            22
# Unnamed: 11                            21
# Unnamed: 12                            21
# Unnamed: 13                            22
# Unnamed: 14                            21
# Unnamed: 15                            22
# Unnamed: 16                            21
# dtype: int64

# %%
teste_df["Disciplina:"].fillna('tsudy', inplace= True)
display(teste_df)
# Out:
#    Disciplina:                             ⠀⠀⠀⠀⠀⠀⠀⠀⠀  \
# 0           RM                                  Nome
# 1        82712                Ariele Justino Arantes
# 2        86543              Bruna Aparecida de Souza
# 3        89457                    Camila da Assunção
# 4        87257                Cyntia Araújo de Souza
# 5        80211                      Eduardo Ferreira
# 6        88683                   Elisa Dias Fernades
# 7        81931             Gabriel do Carmo da Silva
# 8        81203         Giovanna Ruth Alves dos Satos
# 9        82543            Guilherme Augusto Castilho
# 10       87384                Jessé da Silva Fontana
# 11       88481            Leonardo Brito de Oliveira
# 12       82561              Lucas dos Santos Batista
# 13       89228          Natalia Sofia Roque da Costa
# 14       89360                  Renata Pereira Pinto
# 15       88185            Tamires Tavares dos Santos
# 16       88075  Tatiane Antonia Nascimento de Araújo
# ...

# %%
teste_check = teste_df.isnull()

display(teste_check)
# Out:
#     Disciplina:  ⠀⠀⠀⠀⠀⠀⠀⠀⠀  Computational Thinking using Python  ⠀⠀⠀⠀⠀⠀⠀⠀⠀.1  \
# 0         False      False                                False        False
# 1         False      False                                False        False
# 2         False      False                                False        False
# 3         False      False                                False        False
# 4         False      False                                False        False
# 5         False      False                                False        False
# 6         False      False                                False        False
# 7         False      False                                False        False
# 8         False      False                                False        False
# 9         False      False                                False        False
# 10        False      False                                False        False
# ...

# %%
import numpy as np
df = pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, np.nan, 1],
                       [np.nan, np.nan, np.nan, 5]],
                       columns=list('ABCD'))
display(df)
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df.dropna(axis=1, how='all')
# Out:
#      A    B  D
# 0  NaN  2.0  0
# 1  3.0  4.0  1
# 2  NaN  NaN  5

# %%
df.dropna(axis=1, how='any')
# Out:
#    D
# 0  0
# 1  1
# 2  5

# %%
df.dropna(axis=0, how='all')
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df.dropna(thresh=2)
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
